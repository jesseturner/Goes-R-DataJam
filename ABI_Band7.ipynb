# %%
import s3fs
import datetime
import xarray as xr
import numpy as np

import matplotlib as mpl
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors

from cartopy import crs as ccrs
import cartopy.feature as cfeature

from pathlib import Path
from PIL import Image
import os

# %%
fs = s3fs.S3FileSystem(anon=True)

# %%
products = fs.ls('noaa-goes16')

# %% [markdown]
# Set the date and hour for the data of interest:

# %%
year = 2023
month = 3
day = 31
hour = 23

julian_day = datetime.datetime(year, month, day).strftime('%j')
print(julian_day)
# Out:
# 090

# %% [markdown]
# Product chosen: ABI imager (mesoscale)

# %%
bucket = 'noaa-goes16'
product = 'ABI-L1b-RadM'

data_path = bucket + '/' + product + '/'  + str(year) + '/' + julian_day + '/' + str(hour).zfill(2)

files = fs.ls(data_path)

#for file in files:
#    print(file.split('/')[-1])

# %% [markdown]
# M1 refers to mesoscale sector 1, M6 refers to scan mode 6.
#
# Select the start and end times within the hour selected earlier:

# %%
observation_start = '2330'
observation_end = '2400'
product_name_07 = 'ABI-L1b-RadM1-M6C07' #SW IR band (3.9um)

matches_07 = [file for file in files if (file.split('/')[-1].split('_')[3][8:12] >= observation_start and file.split('/')[-1].split('_')[3][8:12] <= observation_end and file.split('/')[-1].split('_')[1] == product_name_07)]

for match_07 in matches_07:
    print(match_07.split('/')[-1])
    print('Approximate file size (MB):', round((fs.size(match_07)/1.0E6), 2))
# Out:
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902330276_e20230902330345_c20230902330383.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902331247_e20230902331322_c20230902331361.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902332247_e20230902332318_c20230902332341.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902333247_e20230902333319_c20230902333350.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902334247_e20230902334318_c20230902334364.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902335247_e20230902335316_c20230902335357.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902336247_e20230902336320_c20230902336341.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902337247_e20230902337316_c20230902337357.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902338247_e20230902338318_c20230902338348.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902339247_e20230902339318_c20230902339354.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902340276_e20230902340346_c20230902340382.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902341247_e20230902341316_c20230902341354.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902342247_e20230902342317_c20230902342368.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902343247_e20230902343316_c20230902343367.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902344247_e20230902344317_c20230902344346.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902345247_e20230902345316_c20230902345368.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902346247_e20230902346316_c20230902346351.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902347247_e20230902347316_c20230902347365.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902348247_e20230902348316_c20230902348363.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902349247_e20230902349322_c20230902349355.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902350276_e20230902350350_c20230902350397.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902351247_e20230902351316_c20230902351351.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902352247_e20230902352316_c20230902352366.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902353247_e20230902353316_c20230902353360.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902354247_e20230902354316_c20230902354358.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902355247_e20230902355316_c20230902355359.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902356247_e20230902356319_c20230902356360.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902357247_e20230902357317_c20230902357359.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902358247_e20230902358317_c20230902358345.nc
# Approximate file size (MB): 0.34
# OR_ABI-L1b-RadM1-M6C07_G16_s20230902359247_e20230902359316_c20230902359349.nc
# Approximate file size (MB): 0.34

# %% [markdown]
# Function to get latitude and longitude from goes fixed grid:

# %%
def calculate_abi_lat_lon(ds):
    
    # Read in GOES ABI fixed grid projection variables and constants
    x_coordinate_1d = ds.x  # E/W scanning angle in radians
    y_coordinate_1d = ds.y  # N/S elevation angle in radians
    projection_info = ds.goes_imager_projection  # ABI fixed grid contstants
    lon_origin = projection_info.longitude_of_projection_origin
    H = projection_info.perspective_point_height+projection_info.semi_major_axis
    r_eq = projection_info.semi_major_axis
    r_pol = projection_info.semi_minor_axis
    
    # Create 2D coordinate matrices from 1D coordinate vectors
    x_coordinate_2d, y_coordinate_2d = np.meshgrid(x_coordinate_1d, y_coordinate_1d)
    
    # Equations to calculate latitude and longitude
    lambda_0 = (lon_origin*np.pi)/180.0  
    a_var = np.power(np.sin(x_coordinate_2d),2.0) + (np.power(np.cos(x_coordinate_2d),2.0)*(np.power(np.cos(y_coordinate_2d),2.0)+(((r_eq*r_eq)/(r_pol*r_pol))*np.power(np.sin(y_coordinate_2d),2.0))))
    b_var = -2.0*H*np.cos(x_coordinate_2d)*np.cos(y_coordinate_2d)
    c_var = (H**2.0)-(r_eq**2.0)
    r_s = (-1.0*b_var - np.sqrt((b_var**2)-(4.0*a_var*c_var)))/(2.0*a_var)
    s_x = r_s*np.cos(x_coordinate_2d)*np.cos(y_coordinate_2d)
    s_y = - r_s*np.sin(x_coordinate_2d)
    s_z = r_s*np.cos(x_coordinate_2d)*np.sin(y_coordinate_2d)
    
    lat = (180.0/np.pi)*(np.arctan(((r_eq*r_eq)/(r_pol*r_pol))*((s_z/np.sqrt(((H-s_x)*(H-s_x))+(s_y*s_y))))))
    lon = (lambda_0 - np.arctan(s_y/(H-s_x)))*(180.0/np.pi)
    
    return lat, lon

# %% [markdown]
# Checking out the mesoscale sector:

# %%
with fs.open(matches_07[0], mode='rb') as remote_file:
    with xr.open_dataset(remote_file, engine='h5netcdf') as ds:
        projection=ccrs.PlateCarree()
        fig,ax=plt.subplots(1, figsize=(12,12),subplot_kw={'projection': projection})
        cmap = plt.cm.PuBu
        #levels = np.linspace(0, 500, 21)

        lat, lon = calculate_abi_lat_lon(ds)
        ax.set_extent([np.nanmin(lon), np.nanmax(lon), np.nanmin(lat), np.nanmax(lat)])
        #ax.set_extent([-67, -125, 25, 49]) --- CONUS

        c=ax.contourf(lon, lat, ds.Rad, cmap=cmap, extend='max')#, levels=levels)
        clb=plt.colorbar(c, shrink=0.3, pad=0.02, ax=ax)
        clb.set_label('Radiance')

        ax.coastlines(resolution='50m', color='black', linewidth=1)
        ax.add_feature(cfeature.STATES)

        time = matches_07[0].split('/')[-1][35:37] +':'+ matches_07[0].split('/')[-1][37:39]
        date = str(year) +'/'+ str(month) +'/'+ str(day)
        title = 'ABI Band 7 [SW IR Window] (' + date + ' ' + time + ' UTC)'
        ax.set_title(title)

# %% [markdown]
# Creating the images for the animation:

# %%
image_dir_07 = 'ABI_Band7_'+str(year)+'_'+str(month)+'_'+str(day)

if not os.path.exists(image_dir_07):
    os.makedirs(image_dir_07)

# %% [markdown]
# Collect for SW IR Window:

# %%
for match in matches_07:
    with fs.open(match, mode='rb') as remote_file:
        with xr.open_dataset(remote_file, engine='h5netcdf') as ds:
            projection=ccrs.PlateCarree()
            fig,ax=plt.subplots(1, figsize=(12,12),subplot_kw={'projection': projection})
            cmap = plt.cm.PuBu
            levels = np.linspace(0, 0.7, 21)

            lat, lon = calculate_abi_lat_lon(ds)
            ax.set_extent([np.nanmin(lon), np.nanmax(lon), np.nanmin(lat), np.nanmax(lat)])
            #ax.set_extent([-67, -125, 25, 49]) --- CONUS

            c=ax.contourf(lon, lat, ds.Rad, cmap=cmap, extend='max', levels=levels)
            clb=plt.colorbar(c, shrink=0.3, pad=0.02, ax=ax)
            clb.set_label('Radiance')

            ax.coastlines(resolution='50m', color='black', linewidth=1)
            ax.add_feature(cfeature.STATES)
            
            time = match.split('/')[-1][35:37] +':'+ match.split('/')[-1][37:39]
            date = str(year) +'/'+ str(month) +'/'+ str(day)
            title = 'ABI Band 7 [SW IR] (' + date + ' ' + time + ' UTC)'
            ax.set_title(title)
            
            saved_file_name = 'ABI_Band7_'+str(year)+'_'+str(month)+'_'+str(day)+'_'+match.split('/')[-1][35:39]
            fig.savefig(image_dir_07+'/'+saved_file_name, dpi=100, bbox_inches='tight')
            
            plt.close()

# %%
def create_pillow_animation(file_list, save_path, save_name, duration, loop):
    frames = [Image.open(file) for file in file_list]

    frames[0].save((save_path / save_name).as_posix() + '.gif', format='GIF', append_images=frames[1:], 
                    save_all=True, duration=duration, loop=loop)
    print('Animation done!')

# %% [markdown]
# Create animation for Band 7:

# %%
pil_duration = 100  # Time in ms between frames (e.g., 1000 ms = 1 second between frames)
pil_loop = 0  # No. times animation repeats (e.g., 0: loops continuously; 2: runs 3 times then stops)
animation_save_path = Path.cwd()  # Directory where animation file will be saved
date = str(year)+'_'+str(month)+'_'+str(day)
animation_save_name = 'ABI_Band7_'+date+'_animation'  # Name for saved animation .gif file

graphics_files = sorted(Path.cwd().glob(image_dir_07+'/ABI_Band7_'+date+'*.png'))

# Create the animation using the function defined previously
create_pillow_animation(graphics_files, animation_save_path, animation_save_name, pil_duration, pil_loop)
# Out:
# Animation done!
